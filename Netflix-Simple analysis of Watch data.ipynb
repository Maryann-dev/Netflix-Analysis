# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib_pyplot as plt

# %%
data= pd.read_csv('C:/Users/Work/Desktop/Netflix data.csv')

data.head()
# Out:
#   Profile Name      Start Time Duration  Attributes  \
# 0      Charlie  3/20/2013 5:17  0:00:05         NaN
# 1      Charlie  3/20/2013 4:27  0:44:31         NaN
# 2      Charlie  3/20/2013 4:05  0:22:06         NaN
# 3      Charlie  3/20/2013 0:20  0:48:14         NaN
# 4      Charlie  3/20/2013 0:10  0:04:51         NaN
#
#                                                Title  Supplemental Video Type  \
# 0  Star Trek: Deep Space Nine: Season 5: Empok No...                      NaN
# 1  Star Trek: Deep Space Nine: Season 5: Blaze of...                      NaN
# 2  Star Trek: Deep Space Nine: Season 5: Children...                      NaN
# 3                                  The Invisible War                      NaN
# 4                                  The Invisible War                      NaN
#
#           Device Type Bookmark  Latest Bookmark             Country
# 0                 Mac  0:00:05  Not latest view  US (United States)
# ...

# %%
data= pd.read_csv('C:/Users/Work/Desktop/Netflix data.csv')

data = data.drop(["Attributes", "Supplemental Video Type","Device Type", "Profile Name", "Latest Bookmark"], axis=1)

data.head(5)
# Out:
#        Start Time Duration                                              Title  \
# 0  3/20/2013 5:17  0:00:05  Star Trek: Deep Space Nine: Season 5: Empok No...
# 1  3/20/2013 4:27  0:44:31  Star Trek: Deep Space Nine: Season 5: Blaze of...
# 2  3/20/2013 4:05  0:22:06  Star Trek: Deep Space Nine: Season 5: Children...
# 3  3/20/2013 0:20  0:48:14                                  The Invisible War
# 4  3/20/2013 0:10  0:04:51                                  The Invisible War
#
#   Bookmark             Country
# 0  0:00:05  US (United States)
# 1  0:44:31  US (United States)
# 2  0:44:37  US (United States)
# 3  0:53:18  US (United States)
# 4  0:05:01  US (United States)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Start Time  200 non-null    object
#  1   Duration    200 non-null    object
#  2   Title       200 non-null    object
#  3   Bookmark    200 non-null    object
#  4   Country     200 non-null    object
# dtypes: object(5)
# memory usage: 7.9+ KB

# %%
data['Start Time']=pd.to_datetime(data['Start Time'])

data.head(20)
# Out:
#             Start Time Duration  \
# 0  2013-03-20 05:17:00  0:00:05
# 1  2013-03-20 04:27:00  0:44:31
# 2  2013-03-20 04:05:00  0:22:06
# 3  2013-03-20 00:20:00  0:48:14
# 4  2013-03-20 00:10:00  0:04:51
# 5  2013-03-19 22:34:00  0:22:29
# 6  2013-03-19 05:07:00  0:33:10
# 7  2013-03-18 23:57:00  0:11:36
# 8  2013-03-18 23:26:00  0:31:32
# 9  2013-03-18 23:25:00  0:00:02
# 10 2013-03-18 23:04:00  0:21:07
# 11 2013-03-18 22:42:00  0:21:30
# 12 2013-03-18 22:21:00  0:20:55
# 13 2013-03-18 22:20:00  0:00:55
# 14 2013-03-18 20:29:00  0:20:15
# 15 2013-03-18 20:07:00  0:21:21
# 16 2013-03-18 19:46:00  0:21:14
# 17 2013-03-18 19:24:00  0:21:34
# 18 2013-03-18 18:20:00  0:21:12
# 19 2013-03-18 17:54:00  0:21:15
#
#                                                 Title Bookmark  \
# 0   Star Trek: Deep Space Nine: Season 5: Empok No...  0:00:05
# 1   Star Trek: Deep Space Nine: Season 5: Blaze of...  0:44:31
# 2   Star Trek: Deep Space Nine: Season 5: Children...  0:44:37
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 134 entries, 1 to 199
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Start Time              134 non-null    datetime64[ns]
#  1   Duration                134 non-null    timedelta64[ns]
#  2   Title                   134 non-null    object
#  3   Bookmark                134 non-null    object
#  4   Country                 134 non-null    object
#  5   (Start Time, Bookmark)  134 non-null    datetime64[ns]
# dtypes: datetime64[ns](2), object(3), timedelta64[ns](1)
# memory usage: 7.3+ KB

# %%
import pandas as pd
data['Duration'] = pd.to_timedelta(data['Duration'])
data.dtypes
# Out:
# Start Time     datetime64[ns]
# Duration      timedelta64[ns]
# Title                  object
# Bookmark               object
# Country                object
# dtype: object

# %%
data = data[(data['Duration'] > '00:15:00')]
data.head(30)
# Out:
#             Start Time        Duration  \
# 1  2013-03-20 04:27:00 0 days 00:44:31
# 2  2013-03-20 04:05:00 0 days 00:22:06
# 3  2013-03-20 00:20:00 0 days 00:48:14
# 5  2013-03-19 22:34:00 0 days 00:22:29
# 6  2013-03-19 05:07:00 0 days 00:33:10
# 8  2013-03-18 23:26:00 0 days 00:31:32
# 10 2013-03-18 23:04:00 0 days 00:21:07
# 11 2013-03-18 22:42:00 0 days 00:21:30
# 12 2013-03-18 22:21:00 0 days 00:20:55
# 14 2013-03-18 20:29:00 0 days 00:20:15
# 15 2013-03-18 20:07:00 0 days 00:21:21
# 16 2013-03-18 19:46:00 0 days 00:21:14
# 17 2013-03-18 19:24:00 0 days 00:21:34
# 18 2013-03-18 18:20:00 0 days 00:21:12
# 19 2013-03-18 17:54:00 0 days 00:21:15
# 20 2013-03-18 17:36:00 0 days 00:15:50
# 22 2013-03-18 05:00:00 0 days 00:21:02
# 23 2013-03-18 04:27:00 0 days 00:32:37
# 25 2013-03-17 05:10:00 0 days 00:20:18
# 26 2013-03-17 04:48:00 0 days 00:21:41
# 27 2013-03-17 04:31:00 0 days 00:15:51
# 29 2013-03-16 19:52:00 0 days 00:21:21
# 30 2013-03-16 19:31:00 0 days 00:21:54
# ...

# %%
data.groupby('Title').Title.count()
# Out:
# Title
# 30 for 30: The Two Escobars                                        1
# Archer: Season 2: Movie Star (Episode 7)                           1
# Archer: Season 2: Pipeline Fever (Episode 4)                       1
# Archer: Season 2: Placebo Effect (Episode 9)                       1
# Archer: Season 2: The Double Deuce (Episode 5)                     1
#                                                                   ..
# The Office (U.S.): Season 7: Threat Level Midnight (Episode 17)    1
# The Office (U.S.): Season 7: Training Day (Episode 20)             1
# The Office (U.S.): Season 7: Ultimatum (Episode 13)                1
# The Office (U.S.): Season 7: Viewing Party (Episode 8)             1
# The Office (U.S.): Season 7: WUPHF.com (Episode 9)                 1
# Name: Title, Length: 130, dtype: int64

# %%
data.isnull()==0
data=data.dropna()

# %%
data.head()
# Out:
#            Start Time        Duration  \
# 1 2013-03-20 04:27:00 0 days 00:44:31
# 2 2013-03-20 04:05:00 0 days 00:22:06
# 3 2013-03-20 00:20:00 0 days 00:48:14
# 5 2013-03-19 22:34:00 0 days 00:22:29
# 6 2013-03-19 05:07:00 0 days 00:33:10
#
#                                                Title Bookmark
# 1  Star Trek: Deep Space Nine: Season 5: Blaze of...  0:44:31
# 2  Star Trek: Deep Space Nine: Season 5: Children...  0:44:37
# 3                                  The Invisible War  0:53:18
# 5  Star Trek: Deep Space Nine: Season 5: Children...  0:22:31
# 6  Star Trek: Deep Space Nine: Season 5: Soldiers...  0:44:42

# %%
import seaborn as sns
sns.countplot(data['Title'])
# Out:
# c:\users\work\appdata\local\programs\python\python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Title', ylabel='count'>

# %%
office = data[data['Title'].str.contains('The Office (U.S.)', regex=False)]

# %%
#How long have we watched the office?
office['Duration'].sum()
# Out:
# Timedelta('1 days 09:56:13')

# %%
office['weekday'] = office['Start Time'].dt.weekday
office['hour'] = office['Start Time'].dt.hour
office.head(1)
# Out:
# <ipython-input-41-3e72aae7ec94>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   office['weekday'] = office['Start Time'].dt.weekday
# <ipython-input-41-3e72aae7ec94>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   office['hour'] = office['Start Time'].dt.hour
#             Start Time        Duration  \
# 10 2013-03-18 23:04:00 0 days 00:21:07
#
#                                                 Title Bookmark  \
# 10  The Office (U.S.): Season 5: Moroccan Christma...  0:21:06
#
# ...

# %%
# %matplotlib inline
import matplotlib
# set our categorical and define the order so the days are plotted Monday-Sunday
office['weekday'] = pd.Categorical(office['weekday'], categories=
    [0,1,2,3,4,5,6], ordered=True)

# create office_by_day and count the rows for each weekday, assigning the result to that variable
office_by_day = office['weekday'].value_counts()

# sort the index using our categorical, so that Monday (0) is first, Tuesday (1) is second, etc.
office_by_day = office_by_day.sort_index()

# optional: update the font size to make it a bit larger and easier to read
matplotlib.rcParams.update({'font.size': 22})

# plot office_by_day as a bar chart with the listed size and title
office_by_day.plot(kind='bar', figsize=(10,5), title='Office Episodes Watched by Day')
# Out:
# <AxesSubplot:title={'center':'Office Episodes Watched by Day'}>
